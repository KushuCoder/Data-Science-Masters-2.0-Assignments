# %% [markdown]
# Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in predicting the quality of wine.

# %% [markdown]
# The key features of the wine quality dataset typically include physicochemical properties such as acidity, alcohol content, and sugar levels. These features are important because they influence the sensory attributes of wine, such as taste and aroma, which are key determinants of wine quality.

# %% [markdown]
# Q2. How did you handle missing data in the wine quality data set during the feature engineering process? Discuss the advantages and disadvantages of different imputation techniques.

# %% [markdown]
# Handling missing data in the wine quality dataset can be done using techniques like mean imputation, median imputation, or predictive modeling. Mean imputation is simple but may distort the data distribution, while predictive modeling can be more accurate but computationally expensive.

# %% [markdown]
# Q3. What are the key factors that affect students' performance in exams? How would you go about analyzing these factors using statistical techniques?

# %% [markdown]
# Key factors affecting students' performance in exams include study hours, attendance, socioeconomic background, and prior knowledge. Analyzing these factors using regression analysis, correlation studies, and hypothesis testing can help identify significant predictors of performance.

# %% [markdown]
# Q4. Describe the process of feature engineering in the context of the student performance data set. How did you select and transform the variables for your model?

# %% [markdown]
# Feature engineering in the student performance dataset involves selecting relevant features such as test scores, attendance, and extracurricular activities. Transformations like normalization and categorical encoding can improve model performance by making data more interpretable.

# %% [markdown]
# Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to these features to improve normality?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
wine_data = pd.read_csv("winequality.csv")
for column in wine_data.columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(wine_data[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.show()
non_normal_features = []
for column in wine_data.columns:
    stat, p = stats.shapiro(wine_data[column])
    if p < 0.05:
        non_normal_features.append(column)

print("Features exhibiting non-normality:", non_normal_features)
for column in non_normal_features:
    wine_data[column] = wine_data[column].apply(lambda x: np.log1p(x))
# Out:
# Features exhibiting non-normality: ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality', 'Id']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 19
#      17 print("Features exhibiting non-normality:", non_normal_features)
#      18 for column in non_normal_features:
# ---> 19     wine_data[column] = wine_data[column].apply(lambda x: np.log1p(x))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
# ...

# %% [markdown]
# Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of features. What is the minimum number of principal components required to explain 90% of the variance in the data?

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np
scaler = StandardScaler()
wine_scaled = scaler.fit_transform(wine_data.drop("quality", axis=1))
pca = PCA()
pca.fit(wine_scaled)
explained_variance = np.cumsum(pca.explained_variance_ratio_)
num_components = np.argmax(explained_variance >= 0.90) + 1
print("Minimum number of principal components required to explain 90% variance:", num_components)
# Out:
# Minimum number of principal components required to explain 90% variance: 8
