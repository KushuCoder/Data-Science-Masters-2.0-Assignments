# %% [markdown]
# # Q1. Explain why we have to use the Exception class while creating a Custom Exception.
# # Note: Here Exception class refers to the base class for all the exceptions.

# %% [markdown]
# When creating a custom exception in Python, it is essential to inherit from the built-in Exception class because it provides the core functionality needed for handling exceptions in a standardized way.
# The Exception class provides useful built-in methods like __str__() for human-readable error messages, inheriting from Exception allows custom exceptions to automatically support these features.
# It integrates well with Python’s built-in exceptions.
# It allows creating a structured hierarchy of custom exceptions.

# %% [markdown]
# # Q2. Write a python program to print Python Exception Hierarchy.

# %%
import sys
def print_exception_hierarchy(base_exception, level=0):
    print(" " * level * 4 + f"- {base_exception.__name__}")
    for subclass in base_exception.__subclasses__():
        print_exception_hierarchy(subclass, level + 1)
print_exception_hierarchy(BaseException)
# Out:
# - BaseException
#     - BaseExceptionGroup
#         - ExceptionGroup
#     - Exception
#         - ArithmeticError
#             - FloatingPointError
#             - OverflowError
#             - ZeroDivisionError
#                 - DivisionByZero
#                 - DivisionUndefined
#             - DecimalException
#                 - Clamped
#                 - Rounded
#                     - Underflow
#                     - Overflow
#                 - Inexact
#                     - Underflow
#                     - Overflow
#                 - Subnormal
#                     - Underflow
#                 - DivisionByZero
#                 - FloatOperation
#                 - InvalidOperation
#                     - ConversionSyntax
#                     - DivisionImpossible
#                     - DivisionUndefined
#                     - InvalidContext
#         - AssertionError
#         - AttributeError
#             - FrozenInstanceError
#         - BufferError
# ...

# %% [markdown]
# # Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# ZeroDivisionError – Raised when dividing by zero.
# OverflowError – Raised when a calculation exceeds the maximum limit.
# FloatingPointError – Raised when a floating-point operation fails

# %%
try:
    result = 10 / 0
except ZeroDivisionError as e:
    print(f"Error: {e}")
import math

try:
    print(math.exp(1000)) 
except OverflowError as e:
    print(f"Error: {e}")
# Out:
# Error: division by zero
# Error: math range error

# %% [markdown]
# # Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %%
#The LookupError class is the base class for errors related to invalid key/index lookups in sequences or mappings. It helps catch errors when accessing non-existent elements.
#key error
try:
    data = {"name": "Alice"}
    print(data["age"]) 
except KeyError as e:
    print(f"Error: Key {e} not found!")
#Index error
try:
    numbers = [1, 2, 3]
    print(numbers[5])  
except IndexError as e:
    print(f"Error: {e}")
# Out:
# Error: Key 'age' not found!
# Error: list index out of range

# %% [markdown]
# # Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# ImportError raises when an import statement fails due to a missing module or incorrect import.
# ModuleNotFoundError is a subclass of ImportError, specifically for missing module cases.

# %% [markdown]
# # Q6. List down some best practices for exception handling in python.

# %% [markdown]
# -Avoid Using raise Unnecessarily, Only raise exceptions when necessary, and use meaningful messages.
# -Use else for Code That Should Run Only if No Exception Occurs, Keeps the try block clean and avoids unintended execution.
# -Create Meaningful Custom Exceptions, Inherit from Exception and use descriptive error messages.
# -Use Built-in Exceptions Where Possible, Avoid unnecessary custom exceptions if a built-in one suffices.
